# %%
#クラスを定義する
class Human:
  def __init__(self,name,age):
    #属性を定義する
    self.name=name
    self.age=age

  #メソッドを定義する
  def printinfo(self):
    print(self.name)
    print(self.age)

#インスタンスを変数に代入する
human = Human("花子",20)

# 値を出力する
human.printinfo()
# Out:
# 花子
# 20
